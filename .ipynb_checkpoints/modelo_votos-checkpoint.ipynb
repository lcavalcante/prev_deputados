# %% [markdown]
# Analise TSE
# ==========

# %% [markdown]
# Initial Configuration
# -----------------------

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats.stats import pearsonr


# %config InlineBackend.figure_format = 'retina' #set 'png' here when working on notebook
# %matplotlib inline
# %config IPCompleter.greedy=True

# %% [markdown]
# Load all data
# ---------------

# %%
complete_set = pd.read_csv("eleicoes_2006_a_2010.csv")
complete_set
# Out:
#        ano  sequencial_candidato                              nome  uf  \
# 0     2006                 10001       JOSÉ LUIZ NOGUEIRA DE SOUSA  AP
# 1     2006                 10002                 LOIVA DE OLIVEIRA  RO
# 2     2006                 10002   MARIA DALVA DE SOUZA FIGUEIREDO  AP
# 3     2006                 10002                    ROMALDO MILANI  MS
# 4     2006                 10003            ANSELMO DE JESUS ABREU  RO
# 5     2006                 10003    JOSÉ RODRIGUES DOS SANTOS NETO  PI
# 6     2006                 10003               JOSÉ TOMAZ DA SILVA  MS
# 7     2006                 10003          LUIZ CARLOS MUNHOZ MEIRA  MG
# 8     2006                 10004               EDILSON VEIRA ROCHA  AP
# 9     2006                 10004     EDUARDO VALVERDE ARAÚJO ALVES  RO
# 10    2006                 10004                  IRINEU RODRIGUES  PR
# 11    2006                 10004          TARCISIO JOÃO ZIMERMMANN  RS
# 12    2006                 10004             WILLIAN GOMES EUGENIO  MG
# 13    2006                 10005          AMAURI GUEDES DE FREITAS  RO
# 14    2006                 10005                ELIAS RAMOS SOARES  MG
# 15    2006                 10005     FRANCISCO ALVES DA CRUZ FILHO  MA
# 16    2006                 10005        GILBERTO JOSÉ SPIER VARGAS  RS
# 17    2006                 10005               GLAYDSTON LIRA GOES  PB
# 18    2006                 10005                 ISAAC SILVA GOMES  AP
# 19    2006                 10005               IVETE MARIA RIBEIRO  MS
# 20    2006                 10005       PAULO HENRIQUE COSTA MATTOS  TO
# 21    2006                 10005             REJANE HALUANE CHAVES  SP
# 22    2006                 10005                   WALDIR BERTULIO  MT
# 23    2006                 10006    CASSIA REGINA DE JESUS MARTINS  SP
# 24    2006                 10006             MARCO ANTONIO CAMENAR  PR
# 25    2006                 10006            MARCOS AIRES RODRIGUES  TO
# 26    2006                 10006          RAIMUNDO RODRIGUES FILHO  SE
# 27    2006                 10006              SILVIO NUNES MACHADO  RS
# 28    2006                 10007        BENJAMIM ZANLORENCI JUNIOR  PR
# 29    2006                 10007              DAISY FERREIRA NETTO  SP
# ...    ...                   ...                               ...  ..
# 7300  2010          270000000011               LUIS CHAVES DO VALE  TO
# 7301  2010          270000000012            LÁZARO BOTELHO MARTINS  TO
# 7302  2010          270000000014        MARIA HELENA BRITO MIRANDA  TO
# 7303  2010          270000000015           MOISÉS NOGUEIRA AVELINO  TO
# 7304  2010          270000000016             OSVALDO DE SOUZA REIS  TO
# 7305  2010          270000000018           RAIMUNDO COIMBRA JÚNIOR  TO
# 7306  2010          270000000019  ROSA MARIA ARAÚJO DE VASCONCELOS  TO
# 7307  2010          270000000020           SANSÃO PEREIRA DA SILVA  TO
# 7308  2010          270000000021               ZULEICA SILVA NEGRI  TO
# 7309  2010          270000000245           ADALBERTO LEITE BARBOSA  TO
# 7310  2010          270000000247          ALEXANDRE SANTIAGO FILHO  TO
# 7311  2010          270000000248             ANTONIO JORGE GODINHO  TO
# 7312  2010          270000000249       CARLOS EDUARDO TORRES GOMES  TO
# 7313  2010          270000000250         CONSUELO APARECIDA JULIAO  TO
# 7314  2010          270000000251            GOIACIARA TAVARES CRUZ  TO
# 7315  2010          270000000252             IRAJA SILVESTRE FILHO  TO
# 7316  2010          270000000254     JOSEFA ALMEIDA DE SOUSA CUNHA  TO
# 7317  2010          270000000256              JOSÉ MAURICIO RABELO  TO
# 7318  2010          270000000257           JUAREZ TÁVORA GONÇALVES  TO
# 7319  2010          270000000258  MARIA AUXILIADORA SEABRA REZENDE  TO
# 7320  2010          270000000259  MARIA DE FATIMA SOARES DE ARAUJO  TO
# 7321  2010          270000000260                NILMAR GAVINO RUIZ  TO
# 7322  2010          270000000261            NUBIO GERMANO DA SILVA  TO
# 7323  2010          270000000262             OTONIEL ANDRADE COSTA  TO
# 7324  2010          270000000263          RAIMUNDO MENDES DA SILVA  TO
# 7325  2010          270000000264            ROBERTO PEREIRA URBANO  TO
# 7326  2010          270000000265    RONALDO DIMAS NOGUEIRA PEREIRA  TO
# 7327  2010          270000000266                      SÉRGIO PERIN  TO
# 7328  2010          270000000267      ÍTALO MARCEL COSTA CONCEIÇÃO  TO
# 7329  2010          270000000501               LEONAM XAVIER GOMES  TO
#
#       partido  quantidade_doacoes  quantidade_doadores  total_receita  \
# 0          PT                   6                    6       16600.00
# 1          PT                  13                   13       22826.00
# 2          PT                  17                   16      148120.80
# 3       PRONA                   6                    6        3001.12
# 4          PT                  48                   48            NaN
# 5         PCO                   6                    6        1771.21
# 6       PRONA                  14                    7         697.00
# 7         PPS                   2                    2       70000.00
# 8          PT                   2                    2        6065.00
# 9          PT                  68                   65      105813.20
# 10        PPS                  13                   13       27745.50
# 11         PT                  61                   54            NaN
# 12        PPS                  24                   23       20322.45
# 13         PT                  13                   13       17035.00
# 14        PPS                   4                    4       13378.50
# 15       PSTU                   1                    1         500.00
# 16         PT                  67                   64      203976.70
# 17       PSDC                   2                    2         185.00
# 18         PT                   1                    1        3815.00
# 19      PRONA                   4                    4       34000.00
# 20       PSOL                  29                   27        9227.35
# 21      PRONA                   6                    6        1879.42
# 22       PSOL                   8                    7        2800.00
# 23      PRONA                   2                    2        1293.54
# 24        PPS                  12                   11        2850.00
# 25       PSOL                   1                    1         600.00
# 26        PDT                   5                    4        1015.05
# 27         PT                  16                   15        5103.22
# 28        PPS                   2                    2        3245.39
# 29      PRONA                   4                    4        2867.84
# ...       ...                 ...                  ...            ...
# 7300      PPS                  35                   33      123837.67
# 7301       PP                 166                  165      279266.92
# 7302       PT                  15                   14      208825.00
# 7303     PMDB                  11                   10      348610.23
# 7304     PMDB                  60                   57      638290.45
# 7305     PMDB                 662                  657      913533.73
# 7306  PC do B                  18                   18       50307.71
# 7307      PHS                   8                    8       57328.87
# 7308     PSDC                   5                    5        8506.75
# 7309      PSC                   9                    9       21620.00
# 7310       PV                   2                    2        3700.00
# 7311      PTB                  10                   10       78231.06
# 7312     PSDB                  41                   41     2105815.95
# 7313     PSDB                   4                    4        5811.00
# 7314       PR                   9                    9      164597.65
# 7315      DEM                  95                   91     1444867.94
# 7316     PRTB                   3                    2       20300.00
# 7317      PRB                  19                   19      130238.57
# 7318       PR                  24                   15       41731.69
# 7319      DEM                  60                   58      685310.49
# 7320      PMN                  13                   13       21755.58
# 7321       PR                  25                   21      562126.67
# 7322      PMN                   7                    7       25625.65
# 7323       PR                  20                   19      441505.12
# 7324      DEM                   4                    4        6545.00
# 7325      PSC                   3                    3        3370.00
# 7326       PR                 715                  706     1034323.16
# 7327      PTB                   2                    2        2600.00
# 7328       PR                   2                    2        5175.00
# 7329      PPS                  13                   12       33852.82
#
#       media_receita  recursos_de_outros_candidatos/comites   ...    \
# 0       2766.666667                                    NaN   ...
# 1       1755.846154                                6625.00   ...
# 2       9257.550000                                2250.00   ...
# 3        500.186667                                    NaN   ...
# 4               NaN                                    NaN   ...
# 5        295.201667                                    NaN   ...
# 6         99.571429                                    NaN   ...
# 7      35000.000000                                    NaN   ...
# 8       3032.500000                                6065.00   ...
# 9       1627.895385                                9575.00   ...
# 10      2134.269231                                1375.50   ...
# 11              NaN                                6295.10   ...
# 12       883.584783                                    NaN   ...
# 13      1310.384615                                1125.00   ...
# 14      3344.625000                                3378.50   ...
# 15       500.000000                                    NaN   ...
# 16      3187.135938                                1628.25   ...
# 17        92.500000                                 185.00   ...
# 18      3815.000000                                3815.00   ...
# 19      8500.000000                                    NaN   ...
# 20       341.753704                                1558.34   ...
# 21       313.236667                                    NaN   ...
# 22       400.000000                                    NaN   ...
# 23       646.770000                                    NaN   ...
# 24       259.090909                                    NaN   ...
# 25       600.000000                                    NaN   ...
# 26       253.762500                                    NaN   ...
# 27       340.214667                                    NaN   ...
# 28      1622.695000                                    NaN   ...
# 29       716.960000                                    NaN   ...
# ...             ...                                    ...   ...
# 7300    3752.656667                               74129.67   ...
# 7301    1692.526788                               42059.67   ...
# 7302   14916.071429                              166525.00   ...
# 7303   34861.023000                              112680.23   ...
# 7304   11198.078070                               43129.67   ...
# 7305    1390.462298                              147589.67   ...
# 7306    2794.872778                               42707.71   ...
# 7307    7166.108750                               57328.87   ...
# 7308    1701.350000                                8506.75   ...
# 7309    2402.222222                               10020.00   ...
# 7310    1850.000000                                3700.00   ...
# 7311    7823.106000                               25231.06   ...
# 7312   51361.364634                              270092.63   ...
# 7313    1452.750000                                5811.00   ...
# 7314   18288.627778                               10897.65   ...
# 7315   15877.669670                              169167.94   ...
# 7316   10150.000000                               40000.00   ...
# 7317    6854.661579                                    NaN   ...
# 7318    2782.112667                                3782.50   ...
# 7319   11815.698103                              385903.95   ...
# 7320    1673.506154                               13165.58   ...
# 7321   26767.936667                              253526.67   ...
# 7322    3660.807143                               10449.00   ...
# 7323   23237.111579                              107952.12   ...
# 7324    1636.250000                                6345.00   ...
# 7325    1123.333333                                 370.00   ...
# 7326    1465.046969                              211804.58   ...
# 7327    1300.000000                                    NaN   ...
# 7328    2587.500000                                3375.00   ...
# 7329    2821.068333                               30083.67   ...
#
#       quantidade_despesas  quantidade_fornecedores  total_despesa  \
# 16                    CASADO(A)
# 17                  SOLTEIRO(A)
# 18                  SOLTEIRO(A)
# 19                DIVORCIADO(A)
# 20                    CASADO(A)
# 21                  SOLTEIRO(A)
# 22                    CASADO(A)
# 23                  SOLTEIRO(A)
# 24                    CASADO(A)
# 25                    CASADO(A)
# 26                    CASADO(A)
# 27                    CASADO(A)
# 28                    CASADO(A)
# 29                DIVORCIADO(A)
# ...                         ...
# 7300                SOLTEIRO(A)
# 7301                  CASADO(A)
# 7302  SEPARADO(A) JUDICIALMENTE
# 7303                  CASADO(A)
# 7304                  CASADO(A)
# 7305                  CASADO(A)
# 7306  SEPARADO(A) JUDICIALMENTE
# 7307                  CASADO(A)
# 7308              DIVORCIADO(A)
# 7309                  CASADO(A)
# 7310                  CASADO(A)
# 7311                SOLTEIRO(A)
# 7312                  CASADO(A)
# 7313                SOLTEIRO(A)
# 7314                   VIÚVO(A)
# 7315                  CASADO(A)
# 7316                  CASADO(A)
# 7317                  CASADO(A)
# 7318                  CASADO(A)
# 7319                  CASADO(A)
# 7320              DIVORCIADO(A)
# 7321                  CASADO(A)
# 7322                SOLTEIRO(A)
# 7323                  CASADO(A)
# 7324                  CASADO(A)
# 7325                  CASADO(A)
# 7326                  CASADO(A)
# 7327                  CASADO(A)
# 7328                  CASADO(A)
# 7329                  CASADO(A)
#
#                                              ocupacao   votos
# 0                                            VEREADOR    8579
# 1                           SERVIDOR PÚBLICO ESTADUAL    2757
# 2                                            PEDAGOGO   17428
# 3                                   MILITAR REFORMADO    1193
# 4                                            DEPUTADO   29401
# 5                            SERVIDOR PÚBLICO FEDERAL    1822
# 6                                              MÉDICO     317
# 7                            SERVIDOR PÚBLICO FEDERAL    2591
# 8                       FEIRANTE, AMBULANTE E MASCATE    2551
# 9                                            DEPUTADO   34631
# 10                                           DEPUTADO   26856
# 11                                           DEPUTADO  106659
# 12                                            GERENTE    1859
# 13                                             OUTROS    3752
# 14               APOSENTADO (EXCETO SERVIDOR PÚBLICO)    8346
# 15                                             OUTROS    4621
# 16                                             MÉDICO  124686
# 17                                        COMERCIANTE     609
# 18                                          VIGILANTE      88
# 19                                           ADVOGADO    4959
# 20                       PROFESSOR DE ENSINO SUPERIOR    1298
# 21                                           ADVOGADO    1220
# 22                       PROFESSOR DE ENSINO SUPERIOR    1507
# 23                                             MÉDICO    1099
# 24                                             OUTROS    1680
# 25                                           ADVOGADO    1145
# 26                                             FISCAL    3500
# 27                                           VEREADOR    4096
# 28                                      ADMINISTRADOR    1440
# 29                                  ASSISTENTE SOCIAL    1025
# ...                                               ...     ...
# 7300                                 POLICIAL MILITAR    9385
# 7301                                         DEPUTADO   41888
# 7302                                        PSICÓLOGO    4818
# 7303                                         DEPUTADO   33464
# 7304                                         DEPUTADO   28227
# 7305                                         DEPUTADO   69372
# 7306      VENDEDOR DE COMÉRCIO VAREJISTA E ATACADISTA     472
# 7307                                 POLICIAL MILITAR     977
# 7308   ESTUDANTE, BOLSISTA, ESTAGIÁRIO E ASSEMELHADOS     638
# 7309  SACERDOTE OU MEMBRO DE ORDEM OU SEITA RELIGIOSA    7793
# 7310                        PROFESSOR DE ENSINO MÉDIO     304
# 7311                                       AGRICULTOR    4933
# 7312                                         DEPUTADO   49455
# 7313                                         ADVOGADO     254
# 7314             APOSENTADO (EXCETO SERVIDOR PÚBLICO)   26108
# 7315                                       EMPRESÁRIO   39301
# 7316                                         ADVOGADO    2555
# 7317                         SERVIDOR PÚBLICO FEDERAL    7828
# 7318                                       EMPRESÁRIO     795
# 7319                                       EMPRESÁRIO   38233
# 7320                                       EMPRESÁRIO     833
# 7321                                         DEPUTADO   32497
# 7322                                       EMPRESÁRIO     192
# 7323                                       ENGENHEIRO   29283
# 7324                                      COMERCIANTE    1302
# 7325                                         ADVOGADO    3013
# 7326                                       ENGENHEIRO   35980
# 7327                                       ODONTÓLOGO      20
# 7328                           BANCÁRIO E ECONOMIÁRIO     293
# 7329                         SERVIDOR PÚBLICO FEDERAL    1248
#
# [7330 rows x 23 columns]

# %% [markdown]
# Create Train and test
# -------------------------

# %%
#remove not representative data
complete_filtered = complete_set.drop(['sequencial_candidato', 'nome', 'uf', 'ocupacao', 'cargo'], axis=1)

train_2006 = complete_set.loc[lambda complete_set : complete_filtered['ano'] == 2006]
test_2010 = complete_set.loc[lambda complete_set : complete_filtered['ano'] == 2010]
#complete_filtered = complete_filtered.drop(['ano'], axis=1)
#train_2006 = train_2006.drop(['ano'], axis=1)
#test_2010 = test_2010.drop(['ano'], axis=1)

# %%
train_2006.votos
# Out:
# 0         8579
# 1         2757
# 2        17428
# 3         1193
# 4        29401
# 5         1822
# 6          317
# 7         2591
# 8         2551
# 9        34631
# 10       26856
# 11      106659
# 12        1859
# 13        3752
# 14        8346
# 15        4621
# 16      124686
# 17         609
# 18          88
# 19        4959
# 20        1298
# 21        1220
# 22        1507
# 23        1099
# 24        1680
# 25        1145
# 26        3500
# 27        4096
# 28        1440
# 29        1025
#          ...
# 3358    205462
# 3359       377
# 3360      2043
# 3361      1310
# 3362      5624
# 3363       636
# 3364       553
# 3365      1326
# 3366      1142
# 3367      2109
# 3368       559
# 3369      1603
# 3370       170
# 3371      1012
# 3372       127
# 3373      1394
# 3374      1274
# 3375    129300
# 3376     39892
# 3377      6466
# 3378     30295
# 3379       192
# 3380      1579
# 3381     18483
# 3382      2580
# 3383      1813
# 3384       808
# 3385      1971
# 3386      7105
# 3387     44953
# Name: votos, Length: 3388, dtype: int64

# %% [markdown]
# Pre Processing
# ------------------

# %%
complete_set.isnull().any()
# Out:
# ano                                      False
# sequencial_candidato                     False
# nome                                     False
# uf                                       False
# partido                                  False
# quantidade_doacoes                       False
# quantidade_doadores                      False
# total_receita                             True
# media_receita                             True
# recursos_de_outros_candidatos/comites     True
# recursos_de_pessoas_fisicas               True
# recursos_de_pessoas_juridicas             True
# recursos_proprios                         True
# quantidade_despesas                      False
# quantidade_fornecedores                  False
# total_despesa                            False
# media_despesa                            False
# cargo                                    False
# sexo                                     False
# grau                                     False
# estado_civil                             False
# ocupacao                                 False
# votos                                    False
# dtype: bool

# %%
complete_set.isnull().sum()
# Out:
# ano                                         0
# sequencial_candidato                        0
# nome                                        0
# uf                                          0
# partido                                     0
# quantidade_doacoes                          0
# quantidade_doadores                         0
# total_receita                             161
# media_receita                             161
# recursos_de_outros_candidatos/comites    2390
# recursos_de_pessoas_fisicas              2683
# recursos_de_pessoas_juridicas            3976
# recursos_proprios                        2388
# quantidade_despesas                         0
# quantidade_fornecedores                     0
# total_despesa                               0
# media_despesa                               0
# cargo                                       0
# sexo                                        0
# grau                                        0
# estado_civil                                0
# ocupacao                                    0
# votos                                       0
# dtype: int64

# %% [markdown]
# Disclaimer
# ------------
# Todas as colunas com valores nulos são relacionadas a receita, se fossem poucas linhas poderiamos apenas descartar esses valores, porém não é o caso. É uma decisão complicada mas como estamos seguindo esse pipeline https://www.kaggle.com/apapiu/regularized-linear-models "Replace the numeric missing values (NaN's) with the mean of their respective columns" aplicaremos a mesma técnica.

# %% [markdown]
# Skewness
# ========

# %% [markdown]
# Quantidade_doacoes
# -------------------------

# %%
matplotlib.rcParams['figure.figsize'] = (12.0, 6.0)

# %%
votos = pd.DataFrame({"log(votos + 1)":np.log1p(train_2006["votos"]), "votos":train_2006["votos"],})
votos.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a20428eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a20101fd0>]],
#       dtype=object)

# %%
#log transform skewed numeric features:
numeric_feats = complete_filtered.dtypes[complete_set.dtypes != "object"].index

print(numeric_feats)
# Out:
# Index(['ano', 'quantidade_doacoes', 'quantidade_doadores', 'total_receita',
#        'media_receita', 'recursos_de_outros_candidatos/comites',
#        'recursos_de_pessoas_fisicas', 'recursos_de_pessoas_juridicas',
#        'recursos_proprios', 'quantidade_despesas', 'quantidade_fornecedores',
#        'total_despesa', 'media_despesa', 'votos'],
#       dtype='object')

# %%
#log transform the target:
train_2006["votos"] = np.log1p(train_2006["votos"])
test_2010["votos"] = np.log1p(test_2010["votos"])


skewed_feats = train_2006[numeric_feats].apply(lambda x: skew(x.dropna()))
skewed_feats = skewed_feats[skewed_feats > 0.75]
skewed_feats = skewed_feats.index

complete_filtered[skewed_feats] = np.log1p(complete_filtered[skewed_feats])



print(skewed_feats)
# Out:
# Index(['quantidade_doacoes', 'quantidade_doadores', 'total_receita',
#        'media_receita', 'recursos_de_outros_candidatos/comites',
#        'recursos_de_pessoas_fisicas', 'recursos_de_pessoas_juridicas',
#        'recursos_proprios', 'quantidade_despesas', 'quantidade_fornecedores',
#        'total_despesa', 'media_despesa'],
#       dtype='object')
# /home/lucascavalcante/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/lucascavalcante/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/lucascavalcante/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in log1p
#   # Remove the CWD from sys.path while we load stuff.

# %%
complete_filtered = pd.get_dummies(complete_filtered)

#complete_filtered.shape

# %%
#filling NA's with the mean of the column:
#complete_filtered.dropna(inplace=True)
#complete_filtered.shape
complete_filtered = complete_filtered.fillna(complete_filtered.mean())

# %%
train_2006_pre = complete_filtered.loc[lambda complete_filtered : complete_filtered['ano'] == 2006]
test_2010_pre = complete_filtered.loc[lambda complete_filtered : complete_filtered['ano'] == 2010]




#train_2006_pre = train_2006_pre.drop(['ano'], axis=1)
#train_2010_pre = train_2010_pre.drop(['ano'], axis=1)

train_2006_pre.shape
# Out:
# (3388, 59)

# %%
train_2006_pre.votos
# Out:
# 0         8579
# 1         2757
# 2        17428
# 3         1193
# 4        29401
# 5         1822
# 6          317
# 7         2591
# 8         2551
# 9        34631
# 10       26856
# 11      106659
# 12        1859
# 13        3752
# 14        8346
# 15        4621
# 16      124686
# 17         609
# 18          88
# 19        4959
# 20        1298
# 21        1220
# 22        1507
# 23        1099
# 24        1680
# 25        1145
# 26        3500
# 27        4096
# 28        1440
# 29        1025
#          ...
# 3358    205462
# 3359       377
# 3360      2043
# 3361      1310
# 3362      5624
# 3363       636
# 3364       553
# 3365      1326
# 3366      1142
# 3367      2109
# 3368       559
# 3369      1603
# 3370       170
# 3371      1012
# 3372       127
# 3373      1394
# 3374      1274
# 3375    129300
# 3376     39892
# 3377      6466
# 3378     30295
# 3379       192
# 3380      1579
# 3381     18483
# 3382      2580
# 3383      1813
# 3384       808
# 3385      1971
# 3386      7105
# 3387     44953
# Name: votos, Length: 3388, dtype: int64

# %%
from sklearn.model_selection import train_test_split

target = pd.DataFrame({"log(votos + 1)":np.log1p(complete_filtered["votos"]), "votos":complete_filtered["votos"],})


X_intermediate, X_test, y_intermediate, y_test = train_test_split(complete_filtered, 
                                                                  complete_filtered.votos, 
                                                                  shuffle=True,
                                                                  test_size=0.2, 
                                                                  random_state=15)

# train/validation split (gives us train and validation sets)
X_train, X_validation, y_train, y_validation = train_test_split(X_intermediate,
                                                                y_intermediate,
                                                                shuffle=False,
                                                                test_size=0.25,
                                                                random_state=2018)

#X_train.drop(['votos', 'ano'], axis=1)
#X_train.drop(['votos', 'ano'], axis=1)

# %%
def calc_train_error(X_train, y_train, model):
    '''returns in-sample error for already fit model.'''
    predictions = model.predict(X_train)
    mse = mean_squared_error(y_train, predictions)
    rmse = np.sqrt(mse)
    return mse
    
def calc_validation_error(X_test, y_test, model):
    '''returns out-of-sample error for already fit model.'''
    predictions = model.predict(X_test)
    mse = mean_squared_error(y_test, predictions)
    rmse = np.sqrt(mse)
    return mse
    
def calc_metrics(X_train, y_train, X_test, y_test, model):
    '''fits model and returns the RMSE for in-sample error and out-of-sample error'''
    model.fit(X_train, y_train)
    train_error = calc_train_error(X_train, y_train, model)
    validation_error = calc_validation_error(X_test, y_test, model)
    return train_error, validation_error

# %%
#X_train = train_2006_pre
#X_test = test_2010_pre
#y_train = train_2006_pre.votos
#y_test = test_2010_pre.votos

# %%
y_train.shape
# Out:
# (3388,)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression


lr = LinearRegression(fit_intercept=True)

train_error, test_error = calc_metrics(X_train, y_train, X_test, y_test, lr)
train_error, test_error = round(train_error, 3), round(test_error, 3)

print('train error: {} | test error: {}'.format(train_error, test_error))
print('train/test: {}'.format(round(test_error/train_error, 1)))
# Out:
# train error: 0.0 | test error: 0.0
# train/test: nan
# /home/lucascavalcante/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# * Train error lower than test error.
# * Test error 30% worse

# %% [markdown]
# #### Isso é um indicador de que possivelmente a variância está alta e há overfitting, para diminuir a complexidade precisamos usar regularizacao

# %% [markdown]
# ## Model Tuning

# %%
votos_2006 = pd.DataFrame({"votos":train_2006_pre["votos"]})

# %%
from sklearn.model_selection import train_test_split

#X_intermediate, X_test, y_intermediate, y_test = train_test_split(complete_filtered, 
#                                                                  votos, 
#                                                                  shuffle=True,
#                                                                  test_size=0.2, 
#                                                                  random_state=15)

# train/validation split (gives us train and validation sets)
X_train, X_validation, y_train, y_validation = train_test_split(train_2006_pre,
                                                                votos_2006,
                                                                shuffle=False,
                                                                test_size=0.25,
                                                                random_state=2018)

X_train.drop(['votos', 'ano'], axis=1)
X_train.drop(['votos', 'ano'], axis=1)

# %%
#X_train.shape
#X_validation.shape
y_validation

# %%
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV, LassoLarsCV
from sklearn.model_selection import cross_val_score

def rmse_cv(model):
    rmse= np.sqrt(-cross_val_score(model, X_train, y_train, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)

# %%
alphas = [0, 0.001, 0.01, 0.03, 0.05, 0.1, 0.3, 0.5, 1, 3, 5, 10, 30, 50, 100]
#ridge_fitting = pd.Series()
train_error = []
test_error = []

i = 0
for alpha in alphas:
    # instantiate and fit model
    ridge = Ridge(alpha=alpha, fit_intercept=True, random_state=99)
    ridge.fit(X_train, y_train)
    # calculate errors
    train_error.append(mean_squared_error(y_train, ridge.predict(X_train)))
    #new_validation_error = mean_squared_error(y_validation, ridge.predict(X_validation))
    test_error.append(mean_squared_error(y_test, ridge.predict(X_test)))
    # print errors as report
    print('alpha: {:7} | train error: {:5} | test error: {}'.
          format(alpha,
                 round(train_error[i],3),
                 #round(new_validation_error,3),
                 round(test_error[i],3)))
    i += 1 

#cv_ridge = [rmse_cv(Ridge(alpha = alpha)).mean() 
#            for alpha in alphas]

# %%
print(len(train_error))
print(len(alphas))

# %%
fig, ax = plt.subplots()

ax.plot(alphas, train_error)
ax.plot(alphas, test_error)

ax.set(xlabel='lambda', ylabel='train_error')
ax.grid()

# %%
model_ridge = Ridge()

# %%
alphas = [0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 50, 75]
cv_ridge = [rmse_cv(Ridge(alpha = alpha)).mean() 
            for alpha in alphas]

# %%
cv_ridge = pd.Series(cv_ridge, index = alphas)
cv_ridge.plot(title = "Validation")
plt.xlabel("alpha")
plt.ylabel("rmse")

# %%
cv_ridge.min()

# %% [markdown]
# Lasso
# -------

# %%
model_lasso = LassoCV(alphas = [1, 0.1, 0.001, 0.0005], max_iter=100000).fit(X_train, y)

# %%
rmse_cv(model_lasso).mean()

# %%
coef = pd.Series(model_lasso.coef_, index = X_train.columns)

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")

# %%
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])

# %%
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")

# %% [markdown]
# Residuals
# --------------

# %%
#let's look at the residuals as well:
matplotlib.rcParams['figure.figsize'] = (6.0, 6.0)

preds = pd.DataFrame({"preds":model_lasso.predict(X_train), "true":y})
preds["residuals"] = preds["true"] - preds["preds"]
preds.plot(x = "preds", y = "residuals",kind = "scatter")

# %%
# delete intermediate variables
del X_intermediate, y_intermediate

# print proportions
print('train: {}% | validation: {}% | test {}%'.format(round(len(y_train)/len(votos),2),
                                                       round(len(y_validation)/len(votos),2),
                                                       round(len(y_test)/len(votos),2)))
